# %%
import os
import requests
from bs4 import BeautifulSoup
import urllib.parse
import time

class ImageCountExceededException(Exception):
    pass

def check_image_count(subspecies, subspecies_counters, threshold=1000):
    if subspecies_counters[subspecies] > threshold:
        raise ImageCountExceededException(f"Subspecies {subspecies} has more than {threshold} images downloaded.")

def download_images(query, num_images, output_dir, subspecies_counters, threshold=1000):
    # Create the directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Set the headers to mimic a browser visit
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
                      "(KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }

    # Format the query for URL encoding
    query_encoded = urllib.parse.quote(query)

    downloaded = 0
    page = 0

    while downloaded < num_images:
        try:
            # Construct the Google Image search URL with pagination
            search_url = f"https://www.google.com/search?q={query_encoded}&tbm=isch&start={page*20}"

            # Get the HTML content of the search page
            response = requests.get(search_url, headers=headers)
            soup = BeautifulSoup(response.text, 'html.parser')

            # Find all image elements
            img_tags = soup.find_all('img')[1:]  # Skip the first image which is usually the Google logo

            if not img_tags:
                break

            for i, img in enumerate(img_tags):
                if downloaded >= num_images:
                    break
                try:
                    img_url = img.get('src') or img.get('data-src')
                    if not img_url or not img_url.startswith('http'):
                        continue
                    img_data = requests.get(img_url).content
                    with open(os.path.join(output_dir, f"{query}_{downloaded}.jpg"), 'wb') as handler:
                        handler.write(img_data)
                    print(f"Downloaded {query}_{downloaded}.jpg")
                    downloaded += 1
                    subspecies_counters[query] += 1

                    # Check if the number of images exceeds the threshold
                    check_image_count(query, subspecies_counters, threshold)

                except Exception as e:
                    print(f"Could not download image {downloaded}: {e}")

            # Increase page count to move to the next set of images
            page += 1

            # Pause to avoid overwhelming the server and to mimic human-like behavior
            time.sleep(5)
        except ImageCountExceededException as e:
            print(e)
            break

# Example usage: Download images related to plant subspecies
plant_species = {
    "rose": ["Rosa gallica", "Rosa chinensis", "Rosa rugosa", "Rosa damascena", "Rosa multiflora"],
    "orchid": ["Phalaenopsis orchids", "Dendrobium orchids", "Cattleya orchids", "Vanda orchids", "Oncidium orchids"],
    "oak": ["Quercus robur", "Quercus petraea", "Quercus suber", "Quercus alba", "Quercus coccinea"],
    "maple": ["Acer saccharum", "Acer rubrum", "Acer platanoides", "Acer palmatum", "Acer macrophyllum"],
    "pine": ["Pinus sylvestris", "Pinus nigra", "Pinus ponderosa", "Pinus strobus", "Pinus contorta"],
    "cactus": ["Carnegiea gigantea", "Echinocactus grusonii", "Opuntia ficus-indica", "Ferocactus wislizeni", "Mammillaria hahniana"],
    "lily": ["Lilium candidum", "Lilium lancifolium", "Lilium longiflorum", "Lilium martagon", "Lilium speciosum"],
    "fern": ["Polypodium vulgare", "Dryopteris filix-mas", "Athyrium filix-femina", "Pteridium aquilinum", "Adiantum pedatum"],
    "bamboo": ["Phyllostachys edulis", "Bambusa vulgaris", "Dendrocalamus asper", "Gigantochloa apus", "Chimonobambusa quadrangularis"],
    "palm": ["Phoenix dactylifera", "Cocos nucifera", "Elaeis guineensis", "Washingtonia robusta", "Areca catechu"]
}

num_images = 1000
output_dir = "/drive/My Drive/Colab Notebooks/plant_subspecies_dataset"

# Dictionary to keep track of the number of images downloaded for each subspecies
subspecies_counters = {f"{species} {subspecies}": 0 for species in plant_species for subspecies in plant_species[species]}

# Create directories for each plant species
for species, subspecies_list in plant_species.items():
    num_images_per_subspecies = num_images_total // len(subspecies_list)
    for subspecies in subspecies_list:
        download_images(f"{species} {subspecies}", num_images_per_subspecies, os.path.join(output_dir, species, subspecies), subspecies_counters)
# Out:
# Downloaded cactus Ferocactus wislizeni_0.jpg
# Downloaded cactus Ferocactus wislizeni_1.jpg
# Downloaded cactus Ferocactus wislizeni_2.jpg
# Downloaded cactus Ferocactus wislizeni_3.jpg
# Downloaded cactus Ferocactus wislizeni_4.jpg
# Downloaded cactus Ferocactus wislizeni_5.jpg
# Downloaded cactus Ferocactus wislizeni_6.jpg
# Downloaded cactus Ferocactus wislizeni_7.jpg
# Downloaded cactus Ferocactus wislizeni_8.jpg
# Downloaded cactus Ferocactus wislizeni_9.jpg
# Downloaded cactus Ferocactus wislizeni_10.jpg
# Downloaded cactus Ferocactus wislizeni_11.jpg
# Downloaded cactus Ferocactus wislizeni_12.jpg
# Downloaded cactus Ferocactus wislizeni_13.jpg
# Downloaded cactus Ferocactus wislizeni_14.jpg
# Downloaded cactus Ferocactus wislizeni_15.jpg
# Downloaded cactus Ferocactus wislizeni_16.jpg
# Downloaded cactus Ferocactus wislizeni_17.jpg
# Downloaded cactus Ferocactus wislizeni_18.jpg
# Downloaded cactus Ferocactus wislizeni_19.jpg
# Downloaded cactus Ferocactus wislizeni_20.jpg
# Downloaded cactus Ferocactus wislizeni_21.jpg
# Downloaded cactus Ferocactus wislizeni_22.jpg
# Downloaded cactus Ferocactus wislizeni_23.jpg
# Downloaded cactus Ferocactus wislizeni_24.jpg
# Downloaded cactus Ferocactus wislizeni_25.jpg
# Downloaded cactus Ferocactus wislizeni_26.jpg
# Downloaded cactus Ferocactus wislizeni_27.jpg
# Downloaded cactus Ferocactus wislizeni_28.jpg
# Downloaded cactus Ferocactus wislizeni_29.jpg
# Downloaded cactus Ferocactus wislizeni_30.jpg
# Downloaded cactus Ferocactus wislizeni_31.jpg
# Downloaded cactus Ferocactus wislizeni_32.jpg
# Downloaded cactus Ferocactus wislizeni_33.jpg
# Downloaded cactus Ferocactus wislizeni_34.jpg
# Downloaded cactus Ferocactus wislizeni_35.jpg
# Downloaded cactus Ferocactus wislizeni_36.jpg
# Downloaded cactus Ferocactus wislizeni_37.jpg
# Downloaded cactus Ferocactus wislizeni_38.jpg
# Downloaded cactus Ferocactus wislizeni_39.jpg
# Downloaded cactus Ferocactus wislizeni_40.jpg
# Downloaded cactus Ferocactus wislizeni_41.jpg
# Downloaded cactus Ferocactus wislizeni_42.jpg
# Downloaded cactus Ferocactus wislizeni_43.jpg
# Downloaded cactus Ferocactus wislizeni_44.jpg
# Downloaded cactus Ferocactus wislizeni_45.jpg
# Downloaded cactus Ferocactus wislizeni_46.jpg
# Downloaded cactus Ferocactus wislizeni_47.jpg
# Downloaded cactus Ferocactus wislizeni_48.jpg
# Downloaded cactus Ferocactus wislizeni_49.jpg
# Downloaded cactus Ferocactus wislizeni_50.jpg
# Downloaded cactus Ferocactus wislizeni_51.jpg
# Downloaded cactus Ferocactus wislizeni_52.jpg
# Downloaded cactus Ferocactus wislizeni_53.jpg
# Downloaded cactus Ferocactus wislizeni_54.jpg
# Downloaded cactus Ferocactus wislizeni_55.jpg
# Downloaded cactus Ferocactus wislizeni_56.jpg
# Downloaded cactus Ferocactus wislizeni_57.jpg
# Downloaded cactus Ferocactus wislizeni_58.jpg
# Downloaded cactus Ferocactus wislizeni_59.jpg
# Downloaded cactus Ferocactus wislizeni_60.jpg
# Downloaded cactus Ferocactus wislizeni_61.jpg
# Downloaded cactus Ferocactus wislizeni_62.jpg
# Downloaded cactus Ferocactus wislizeni_63.jpg
# Downloaded cactus Ferocactus wislizeni_64.jpg
# Downloaded cactus Ferocactus wislizeni_65.jpg
# Downloaded cactus Ferocactus wislizeni_66.jpg
# Downloaded cactus Ferocactus wislizeni_67.jpg
# Downloaded cactus Ferocactus wislizeni_68.jpg
# Downloaded cactus Ferocactus wislizeni_69.jpg
# Downloaded cactus Ferocactus wislizeni_70.jpg
# Downloaded cactus Ferocactus wislizeni_71.jpg
# Downloaded cactus Ferocactus wislizeni_72.jpg
# Downloaded cactus Ferocactus wislizeni_73.jpg
# Downloaded cactus Ferocactus wislizeni_74.jpg
# Downloaded cactus Ferocactus wislizeni_75.jpg
# Downloaded cactus Ferocactus wislizeni_76.jpg
# Downloaded cactus Ferocactus wislizeni_77.jpg
# Downloaded cactus Ferocactus wislizeni_78.jpg
# Downloaded cactus Ferocactus wislizeni_79.jpg
# Downloaded cactus Ferocactus wislizeni_80.jpg
# Downloaded cactus Ferocactus wislizeni_81.jpg
# Downloaded cactus Ferocactus wislizeni_82.jpg
# Downloaded cactus Ferocactus wislizeni_83.jpg
# Downloaded cactus Ferocactus wislizeni_84.jpg
# Downloaded cactus Ferocactus wislizeni_85.jpg
# Downloaded cactus Ferocactus wislizeni_86.jpg
# Downloaded cactus Ferocactus wislizeni_87.jpg
# Downloaded cactus Ferocactus wislizeni_88.jpg
# Downloaded cactus Ferocactus wislizeni_89.jpg
# Downloaded cactus Ferocactus wislizeni_90.jpg
# Downloaded cactus Ferocactus wislizeni_91.jpg
# Downloaded cactus Ferocactus wislizeni_92.jpg
# Downloaded cactus Ferocactus wislizeni_93.jpg
# Downloaded cactus Ferocactus wislizeni_94.jpg
# Downloaded cactus Ferocactus wislizeni_95.jpg
# Downloaded cactus Ferocactus wislizeni_96.jpg
# Downloaded cactus Ferocactus wislizeni_97.jpg
# Downloaded cactus Ferocactus wislizeni_98.jpg
# Downloaded cactus Ferocactus wislizeni_99.jpg
# Downloaded cactus Ferocactus wislizeni_100.jpg
# Downloaded cactus Ferocactus wislizeni_101.jpg
# Downloaded cactus Ferocactus wislizeni_102.jpg
# Downloaded cactus Ferocactus wislizeni_103.jpg
# Downloaded cactus Ferocactus wislizeni_104.jpg
# Downloaded cactus Ferocactus wislizeni_105.jpg
# Downloaded cactus Ferocactus wislizeni_106.jpg
# Downloaded cactus Ferocactus wislizeni_107.jpg
# Downloaded cactus Ferocactus wislizeni_108.jpg
# Downloaded cactus Ferocactus wislizeni_109.jpg
# Downloaded cactus Ferocactus wislizeni_110.jpg
# Downloaded cactus Ferocactus wislizeni_111.jpg
# Downloaded cactus Ferocactus wislizeni_112.jpg
# Downloaded cactus Ferocactus wislizeni_113.jpg
# Downloaded cactus Ferocactus wislizeni_114.jpg
# Downloaded cactus Ferocactus wislizeni_115.jpg
# Downloaded cactus Ferocactus wislizeni_116.jpg
# Downloaded cactus Ferocactus wislizeni_117.jpg
# Downloaded cactus Ferocactus wislizeni_118.jpg
# Downloaded cactus Ferocactus wislizeni_119.jpg
# Downloaded cactus Ferocactus wislizeni_120.jpg
# Downloaded cactus Ferocactus wislizeni_121.jpg
# Downloaded cactus Ferocactus wislizeni_122.jpg
# Downloaded cactus Ferocactus wislizeni_123.jpg
# Downloaded cactus Ferocactus wislizeni_124.jpg
# Downloaded cactus Ferocactus wislizeni_125.jpg
# Downloaded cactus Ferocactus wislizeni_126.jpg
# Downloaded cactus Ferocactus wislizeni_127.jpg
# Downloaded cactus Ferocactus wislizeni_128.jpg
# Downloaded cactus Ferocactus wislizeni_129.jpg
# Downloaded cactus Ferocactus wislizeni_130.jpg
# Downloaded cactus Ferocactus wislizeni_131.jpg
# Downloaded cactus Ferocactus wislizeni_132.jpg
# Downloaded cactus Ferocactus wislizeni_133.jpg
# Downloaded cactus Ferocactus wislizeni_134.jpg
# Downloaded cactus Ferocactus wislizeni_135.jpg
# Downloaded cactus Ferocactus wislizeni_136.jpg
# Downloaded cactus Ferocactus wislizeni_137.jpg
# Downloaded cactus Ferocactus wislizeni_138.jpg
# Downloaded cactus Ferocactus wislizeni_139.jpg
# Downloaded cactus Ferocactus wislizeni_140.jpg
# Downloaded cactus Ferocactus wislizeni_141.jpg
# Downloaded cactus Ferocactus wislizeni_142.jpg
# Downloaded cactus Ferocactus wislizeni_143.jpg
# Downloaded cactus Ferocactus wislizeni_144.jpg
# Downloaded cactus Ferocactus wislizeni_145.jpg
# Downloaded cactus Ferocactus wislizeni_146.jpg
# Downloaded cactus Ferocactus wislizeni_147.jpg
# Downloaded cactus Ferocactus wislizeni_148.jpg
# Downloaded cactus Ferocactus wislizeni_149.jpg
# Downloaded cactus Ferocactus wislizeni_150.jpg
# Downloaded cactus Ferocactus wislizeni_151.jpg
# Downloaded cactus Ferocactus wislizeni_152.jpg
# Downloaded cactus Ferocactus wislizeni_153.jpg
# Downloaded cactus Ferocactus wislizeni_154.jpg
# Downloaded cactus Ferocactus wislizeni_155.jpg
# Downloaded cactus Ferocactus wislizeni_156.jpg
# Downloaded cactus Ferocactus wislizeni_157.jpg
# Downloaded cactus Ferocactus wislizeni_158.jpg
# Downloaded cactus Ferocactus wislizeni_159.jpg
# Downloaded cactus Ferocactus wislizeni_160.jpg
# Downloaded cactus Ferocactus wislizeni_161.jpg
# Downloaded cactus Ferocactus wislizeni_162.jpg
# Downloaded cactus Ferocactus wislizeni_163.jpg
# Downloaded cactus Ferocactus wislizeni_164.jpg
# Downloaded cactus Ferocactus wislizeni_165.jpg
# Downloaded cactus Ferocactus wislizeni_166.jpg
# Downloaded cactus Ferocactus wislizeni_167.jpg
# Downloaded cactus Ferocactus wislizeni_168.jpg
# Downloaded cactus Ferocactus wislizeni_169.jpg
# Downloaded cactus Ferocactus wislizeni_170.jpg
# Downloaded cactus Ferocactus wislizeni_171.jpg
# Downloaded cactus Ferocactus wislizeni_172.jpg
# Downloaded cactus Ferocactus wislizeni_173.jpg
# Downloaded cactus Ferocactus wislizeni_174.jpg
# Downloaded cactus Ferocactus wislizeni_175.jpg
# Downloaded lily Lilium speciosum_0.jpg
# Downloaded lily Lilium speciosum_1.jpg
# Downloaded lily Lilium speciosum_2.jpg
# Downloaded lily Lilium speciosum_3.jpg
# Downloaded lily Lilium speciosum_4.jpg
# Downloaded lily Lilium speciosum_5.jpg
# Downloaded lily Lilium speciosum_6.jpg
# Downloaded lily Lilium speciosum_7.jpg
# Downloaded lily Lilium speciosum_8.jpg
# Downloaded lily Lilium speciosum_9.jpg
# Downloaded lily Lilium speciosum_10.jpg
# Downloaded lily Lilium speciosum_11.jpg
# Downloaded lily Lilium speciosum_12.jpg
# Downloaded lily Lilium speciosum_13.jpg
# Downloaded lily Lilium speciosum_14.jpg
# Downloaded lily Lilium speciosum_15.jpg
# Downloaded lily Lilium speciosum_16.jpg
# Downloaded lily Lilium speciosum_17.jpg
# Downloaded lily Lilium speciosum_18.jpg
# Downloaded lily Lilium speciosum_19.jpg
# Downloaded lily Lilium speciosum_20.jpg
# Downloaded lily Lilium speciosum_21.jpg
# Downloaded lily Lilium speciosum_22.jpg
# Downloaded lily Lilium speciosum_23.jpg
# Downloaded lily Lilium speciosum_24.jpg
# Downloaded lily Lilium speciosum_25.jpg
# Downloaded lily Lilium speciosum_26.jpg
# Downloaded lily Lilium speciosum_27.jpg
# Downloaded lily Lilium speciosum_28.jpg
# Downloaded lily Lilium speciosum_29.jpg
# Downloaded lily Lilium speciosum_30.jpg
# Downloaded lily Lilium speciosum_31.jpg
# Downloaded lily Lilium speciosum_32.jpg
# Downloaded lily Lilium speciosum_33.jpg
# Downloaded lily Lilium speciosum_34.jpg
# Downloaded lily Lilium speciosum_35.jpg
# Downloaded lily Lilium speciosum_36.jpg
# Downloaded lily Lilium speciosum_37.jpg
# Downloaded lily Lilium speciosum_38.jpg
# Downloaded lily Lilium speciosum_39.jpg
# Downloaded lily Lilium speciosum_40.jpg
# Downloaded lily Lilium speciosum_41.jpg
# Downloaded lily Lilium speciosum_42.jpg
# Downloaded lily Lilium speciosum_43.jpg
# Downloaded lily Lilium speciosum_44.jpg
# Downloaded lily Lilium speciosum_45.jpg
# Downloaded lily Lilium speciosum_46.jpg
# Downloaded lily Lilium speciosum_47.jpg
# Downloaded lily Lilium speciosum_48.jpg
# Downloaded lily Lilium speciosum_49.jpg
# Downloaded lily Lilium speciosum_50.jpg
# Downloaded lily Lilium speciosum_51.jpg
# Downloaded lily Lilium speciosum_52.jpg
# Downloaded lily Lilium speciosum_53.jpg
# Downloaded lily Lilium speciosum_54.jpg
# Downloaded lily Lilium speciosum_55.jpg
# Downloaded lily Lilium speciosum_56.jpg
# Downloaded lily Lilium speciosum_57.jpg
# Downloaded lily Lilium speciosum_58.jpg
# Downloaded lily Lilium speciosum_59.jpg
# Downloaded lily Lilium speciosum_60.jpg
# Downloaded lily Lilium speciosum_61.jpg
# Downloaded lily Lilium speciosum_62.jpg
# Downloaded lily Lilium speciosum_63.jpg
# Downloaded lily Lilium speciosum_64.jpg
# Downloaded lily Lilium speciosum_65.jpg
# Downloaded lily Lilium speciosum_66.jpg
# Downloaded lily Lilium speciosum_67.jpg
# Downloaded lily Lilium speciosum_68.jpg
# Downloaded lily Lilium speciosum_69.jpg
# Downloaded lily Lilium speciosum_70.jpg
# Downloaded lily Lilium speciosum_71.jpg
# Downloaded lily Lilium speciosum_72.jpg
# Downloaded lily Lilium speciosum_73.jpg
# Downloaded lily Lilium speciosum_74.jpg
# Downloaded lily Lilium speciosum_75.jpg
# Downloaded lily Lilium speciosum_76.jpg
# Downloaded lily Lilium speciosum_77.jpg
# Downloaded lily Lilium speciosum_78.jpg
# Downloaded lily Lilium speciosum_79.jpg
# Downloaded lily Lilium speciosum_80.jpg
# Downloaded lily Lilium speciosum_81.jpg
# Downloaded lily Lilium speciosum_82.jpg
# Downloaded lily Lilium speciosum_83.jpg
# Downloaded lily Lilium speciosum_84.jpg
# Downloaded lily Lilium speciosum_85.jpg
# Downloaded lily Lilium speciosum_86.jpg
# Downloaded lily Lilium speciosum_87.jpg
# Downloaded lily Lilium speciosum_88.jpg
# Downloaded lily Lilium speciosum_89.jpg
# Downloaded lily Lilium speciosum_90.jpg
# Downloaded lily Lilium speciosum_91.jpg
# Downloaded lily Lilium speciosum_92.jpg
# Downloaded lily Lilium speciosum_93.jpg
# Downloaded lily Lilium speciosum_94.jpg
# Downloaded lily Lilium speciosum_95.jpg
# Downloaded lily Lilium speciosum_96.jpg
# Downloaded lily Lilium speciosum_97.jpg
# Downloaded lily Lilium speciosum_98.jpg
# Downloaded lily Lilium speciosum_99.jpg
# Downloaded lily Lilium speciosum_100.jpg
# Downloaded lily Lilium speciosum_101.jpg
# Downloaded lily Lilium speciosum_102.jpg
# Downloaded lily Lilium speciosum_103.jpg
# Downloaded lily Lilium speciosum_104.jpg
# Downloaded lily Lilium speciosum_105.jpg
# Downloaded lily Lilium speciosum_106.jpg
# Downloaded lily Lilium speciosum_107.jpg
# Downloaded lily Lilium speciosum_108.jpg
# Downloaded lily Lilium speciosum_109.jpg
# Downloaded lily Lilium speciosum_110.jpg
# Downloaded lily Lilium speciosum_111.jpg
# Downloaded lily Lilium speciosum_112.jpg
# Downloaded lily Lilium speciosum_113.jpg
# Downloaded lily Lilium speciosum_114.jpg
# Downloaded lily Lilium speciosum_115.jpg
# Downloaded lily Lilium speciosum_116.jpg
# Downloaded lily Lilium speciosum_117.jpg
# Downloaded lily Lilium speciosum_118.jpg
# Downloaded lily Lilium speciosum_119.jpg
# Downloaded lily Lilium speciosum_120.jpg
# Downloaded lily Lilium speciosum_121.jpg
# Downloaded lily Lilium speciosum_122.jpg
# Downloaded lily Lilium speciosum_123.jpg
# Downloaded lily Lilium speciosum_124.jpg
# Downloaded lily Lilium speciosum_125.jpg
# Downloaded lily Lilium speciosum_126.jpg
# Downloaded lily Lilium speciosum_127.jpg
# Downloaded lily Lilium speciosum_128.jpg
# Downloaded lily Lilium speciosum_129.jpg
# Downloaded lily Lilium speciosum_130.jpg
# Downloaded lily Lilium speciosum_131.jpg
# Downloaded lily Lilium speciosum_132.jpg
# Downloaded lily Lilium speciosum_133.jpg
# Downloaded lily Lilium speciosum_134.jpg
# Downloaded lily Lilium speciosum_135.jpg
# Downloaded lily Lilium speciosum_136.jpg
# Downloaded lily Lilium speciosum_137.jpg
# Downloaded lily Lilium speciosum_138.jpg
# Downloaded lily Lilium speciosum_139.jpg
# Downloaded lily Lilium speciosum_140.jpg
# Downloaded lily Lilium speciosum_141.jpg
# Downloaded lily Lilium speciosum_142.jpg
# Downloaded lily Lilium speciosum_143.jpg
# Downloaded lily Lilium speciosum_144.jpg
# Downloaded lily Lilium speciosum_145.jpg
# Downloaded lily Lilium speciosum_146.jpg
# Downloaded lily Lilium speciosum_147.jpg
# Downloaded lily Lilium speciosum_148.jpg
# Downloaded lily Lilium speciosum_149.jpg
# Downloaded lily Lilium speciosum_150.jpg
# Downloaded lily Lilium speciosum_151.jpg
# Downloaded lily Lilium speciosum_152.jpg
# Downloaded lily Lilium speciosum_153.jpg
# Downloaded lily Lilium speciosum_154.jpg
# Downloaded lily Lilium speciosum_155.jpg
# Downloaded lily Lilium speciosum_156.jpg
# Downloaded lily Lilium speciosum_157.jpg
# Downloaded lily Lilium speciosum_158.jpg
# Downloaded lily Lilium speciosum_159.jpg
# Downloaded lily Lilium speciosum_160.jpg
# Downloaded lily Lilium speciosum_161.jpg
# Downloaded lily Lilium speciosum_162.jpg
# Downloaded lily Lilium speciosum_163.jpg
# Downloaded lily Lilium speciosum_164.jpg
# Downloaded lily Lilium speciosum_165.jpg
# Downloaded lily Lilium speciosum_166.jpg
# Downloaded lily Lilium speciosum_167.jpg
# Downloaded lily Lilium speciosum_168.jpg
# Downloaded lily Lilium speciosum_169.jpg
# Downloaded lily Lilium speciosum_170.jpg
# Downloaded lily Lilium speciosum_171.jpg
# Downloaded lily Lilium speciosum_172.jpg
# Downloaded lily Lilium speciosum_173.jpg
# Downloaded fern Athyrium filix-femina_0.jpg
# Downloaded fern Athyrium filix-femina_1.jpg
# Downloaded fern Athyrium filix-femina_2.jpg
# Downloaded fern Athyrium filix-femina_3.jpg
# Downloaded fern Athyrium filix-femina_4.jpg
# Downloaded fern Athyrium filix-femina_5.jpg
# Downloaded fern Athyrium filix-femina_6.jpg
# Downloaded fern Athyrium filix-femina_7.jpg
# Downloaded fern Athyrium filix-femina_8.jpg
# Downloaded fern Athyrium filix-femina_9.jpg
# Downloaded fern Athyrium filix-femina_10.jpg
# Downloaded fern Athyrium filix-femina_11.jpg
# Downloaded fern Athyrium filix-femina_12.jpg
# Downloaded fern Athyrium filix-femina_13.jpg
# Downloaded fern Athyrium filix-femina_14.jpg
# Downloaded fern Athyrium filix-femina_15.jpg
# Downloaded fern Athyrium filix-femina_16.jpg
# Downloaded fern Athyrium filix-femina_17.jpg
# Downloaded fern Athyrium filix-femina_18.jpg
# Downloaded fern Athyrium filix-femina_19.jpg
# Downloaded fern Athyrium filix-femina_20.jpg
# Downloaded fern Athyrium filix-femina_21.jpg
# Downloaded fern Athyrium filix-femina_22.jpg
# Downloaded fern Athyrium filix-femina_23.jpg
# Downloaded fern Athyrium filix-femina_24.jpg
# Downloaded fern Athyrium filix-femina_25.jpg
# Downloaded fern Athyrium filix-femina_26.jpg
# Downloaded fern Athyrium filix-femina_27.jpg
# Downloaded fern Athyrium filix-femina_28.jpg
# Downloaded fern Athyrium filix-femina_29.jpg
# Downloaded fern Athyrium filix-femina_30.jpg
# Downloaded fern Athyrium filix-femina_31.jpg
# Downloaded fern Athyrium filix-femina_32.jpg
# Downloaded fern Athyrium filix-femina_33.jpg
# Downloaded fern Athyrium filix-femina_34.jpg
# Downloaded fern Athyrium filix-femina_35.jpg
# Downloaded fern Athyrium filix-femina_36.jpg
# Downloaded fern Athyrium filix-femina_37.jpg
# Downloaded fern Athyrium filix-femina_38.jpg
# Downloaded fern Athyrium filix-femina_39.jpg
# Downloaded fern Athyrium filix-femina_40.jpg
# Downloaded fern Athyrium filix-femina_41.jpg
# Downloaded fern Athyrium filix-femina_42.jpg
# Downloaded fern Athyrium filix-femina_43.jpg
# Downloaded fern Athyrium filix-femina_44.jpg
# Downloaded fern Athyrium filix-femina_45.jpg
# Downloaded fern Athyrium filix-femina_46.jpg
# Downloaded fern Athyrium filix-femina_47.jpg
# Downloaded fern Athyrium filix-femina_48.jpg
# Downloaded fern Athyrium filix-femina_49.jpg
# Downloaded fern Athyrium filix-femina_50.jpg
# Downloaded fern Athyrium filix-femina_51.jpg
# Downloaded fern Athyrium filix-femina_52.jpg
# Downloaded fern Athyrium filix-femina_53.jpg
# Downloaded fern Athyrium filix-femina_54.jpg
# Downloaded fern Athyrium filix-femina_55.jpg
# Downloaded fern Athyrium filix-femina_56.jpg
# Downloaded fern Athyrium filix-femina_57.jpg
# Downloaded fern Athyrium filix-femina_58.jpg
# Downloaded fern Athyrium filix-femina_59.jpg
# Downloaded fern Athyrium filix-femina_60.jpg
# Downloaded fern Athyrium filix-femina_61.jpg
# Downloaded fern Athyrium filix-femina_62.jpg
# Downloaded fern Athyrium filix-femina_63.jpg
# Downloaded fern Athyrium filix-femina_64.jpg
# Downloaded fern Athyrium filix-femina_65.jpg
# Downloaded fern Athyrium filix-femina_66.jpg
# Downloaded fern Athyrium filix-femina_67.jpg
# Downloaded fern Athyrium filix-femina_68.jpg
# Downloaded fern Athyrium filix-femina_69.jpg
# Downloaded fern Athyrium filix-femina_70.jpg
# Downloaded fern Athyrium filix-femina_71.jpg
# Downloaded fern Athyrium filix-femina_72.jpg
# Downloaded fern Athyrium filix-femina_73.jpg
# Downloaded fern Athyrium filix-femina_74.jpg
# Downloaded fern Athyrium filix-femina_75.jpg
# Downloaded fern Athyrium filix-femina_76.jpg
# Downloaded fern Athyrium filix-femina_77.jpg
# Downloaded fern Athyrium filix-femina_78.jpg
# Downloaded fern Athyrium filix-femina_79.jpg
# Downloaded fern Athyrium filix-femina_80.jpg
# Downloaded fern Athyrium filix-femina_81.jpg
# Downloaded fern Athyrium filix-femina_82.jpg
# Downloaded fern Athyrium filix-femina_83.jpg
# Downloaded fern Athyrium filix-femina_84.jpg
# Downloaded fern Athyrium filix-femina_85.jpg
# Downloaded fern Athyrium filix-femina_86.jpg
# Downloaded fern Athyrium filix-femina_87.jpg
# Downloaded fern Athyrium filix-femina_88.jpg
# Downloaded fern Athyrium filix-femina_89.jpg
# Downloaded fern Athyrium filix-femina_90.jpg
# Downloaded fern Athyrium filix-femina_91.jpg
# Downloaded fern Athyrium filix-femina_92.jpg
# Downloaded fern Athyrium filix-femina_93.jpg
# Downloaded fern Athyrium filix-femina_94.jpg
# Downloaded fern Athyrium filix-femina_95.jpg
# Downloaded fern Athyrium filix-femina_96.jpg
# Downloaded fern Athyrium filix-femina_97.jpg
# Downloaded fern Athyrium filix-femina_98.jpg
# Downloaded fern Athyrium filix-femina_99.jpg
# Downloaded fern Athyrium filix-femina_100.jpg
# Downloaded fern Athyrium filix-femina_101.jpg
# Downloaded fern Athyrium filix-femina_102.jpg
# Downloaded fern Athyrium filix-femina_103.jpg
# Downloaded fern Athyrium filix-femina_104.jpg
# Downloaded fern Athyrium filix-femina_105.jpg
# Downloaded fern Athyrium filix-femina_106.jpg
# Downloaded fern Athyrium filix-femina_107.jpg
# Downloaded fern Athyrium filix-femina_108.jpg
# Downloaded fern Athyrium filix-femina_109.jpg
# Downloaded fern Athyrium filix-femina_110.jpg
# Downloaded fern Athyrium filix-femina_111.jpg
# Downloaded fern Athyrium filix-femina_112.jpg
# Downloaded fern Athyrium filix-femina_113.jpg
# Downloaded fern Athyrium filix-femina_114.jpg
# Downloaded fern Athyrium filix-femina_115.jpg
# Downloaded fern Athyrium filix-femina_116.jpg
# Downloaded fern Athyrium filix-femina_117.jpg
# Downloaded fern Athyrium filix-femina_118.jpg
# Downloaded fern Athyrium filix-femina_119.jpg
# Downloaded fern Athyrium filix-femina_120.jpg
# Downloaded fern Athyrium filix-femina_121.jpg
# Downloaded fern Athyrium filix-femina_122.jpg
# Downloaded fern Athyrium filix-femina_123.jpg
# Downloaded fern Athyrium filix-femina_124.jpg
# Downloaded fern Athyrium filix-femina_125.jpg
# Downloaded fern Athyrium filix-femina_126.jpg
# Downloaded fern Athyrium filix-femina_127.jpg
# Downloaded fern Athyrium filix-femina_128.jpg
# Downloaded fern Athyrium filix-femina_129.jpg
# Downloaded fern Athyrium filix-femina_130.jpg
# Downloaded fern Athyrium filix-femina_131.jpg
# Downloaded fern Athyrium filix-femina_132.jpg
# Downloaded fern Athyrium filix-femina_133.jpg
# Downloaded fern Athyrium filix-femina_134.jpg
# Downloaded fern Athyrium filix-femina_135.jpg
# Downloaded fern Athyrium filix-femina_136.jpg
# Downloaded fern Athyrium filix-femina_137.jpg
# Downloaded fern Athyrium filix-femina_138.jpg
# Downloaded fern Athyrium filix-femina_139.jpg
# Downloaded fern Athyrium filix-femina_140.jpg
# Downloaded fern Athyrium filix-femina_141.jpg
# Downloaded fern Athyrium filix-femina_142.jpg
# Downloaded fern Athyrium filix-femina_143.jpg
# Downloaded fern Athyrium filix-femina_144.jpg
# Downloaded fern Athyrium filix-femina_145.jpg
# Downloaded fern Athyrium filix-femina_146.jpg
# Downloaded fern Athyrium filix-femina_147.jpg
# Downloaded fern Athyrium filix-femina_148.jpg
# Downloaded fern Athyrium filix-femina_149.jpg
# Downloaded fern Athyrium filix-femina_150.jpg
# Downloaded fern Athyrium filix-femina_151.jpg
# Downloaded fern Athyrium filix-femina_152.jpg
# Downloaded fern Athyrium filix-femina_153.jpg
# Downloaded fern Athyrium filix-femina_154.jpg
# Downloaded fern Athyrium filix-femina_155.jpg
# Downloaded fern Athyrium filix-femina_156.jpg
# Downloaded fern Athyrium filix-femina_157.jpg
# Downloaded fern Athyrium filix-femina_158.jpg
# Downloaded fern Athyrium filix-femina_159.jpg
# Downloaded fern Athyrium filix-femina_160.jpg
# Downloaded fern Athyrium filix-femina_161.jpg
# Downloaded fern Athyrium filix-femina_162.jpg
# Downloaded fern Athyrium filix-femina_163.jpg
# Downloaded fern Athyrium filix-femina_164.jpg
# Downloaded fern Athyrium filix-femina_165.jpg
# Downloaded fern Athyrium filix-femina_166.jpg
# Downloaded fern Athyrium filix-femina_167.jpg
# Downloaded fern Athyrium filix-femina_168.jpg
# Downloaded fern Athyrium filix-femina_169.jpg
# Downloaded fern Athyrium filix-femina_170.jpg
# Downloaded fern Athyrium filix-femina_171.jpg
# Downloaded fern Athyrium filix-femina_172.jpg
# Downloaded fern Athyrium filix-femina_173.jpg

# %%
import os

output_dir = "/drive/My Drive/Colab Notebooks/plant_subspecies_dataset"

def count_images(output_dir):
    subspecies_counts = {}

    for root, dirs, files in os.walk(output_dir):
        for file in files:
            if file.endswith(".jpg"):
                # Extract subspecies name from the file name
                subspecies_name = os.path.basename(file).split("_")[0]
                if subspecies_name not in subspecies_counts:
                    subspecies_counts[subspecies_name] = 0
                subspecies_counts[subspecies_name] += 1

    return subspecies_counts

# Call the function to count images
subspecies_counts = count_images(output_dir)

# Print the counts
for subspecies, count in subspecies_counts.items():
    print(f"{subspecies}: {count} images downloaded")
# Out:
# bamboo: 877 images downloaded
# bamboo Dendrocalamus asper: 176 images downloaded
# bamboo Bambusa vulgaris: 174 images downloaded
# rose Rosa damascena: 174 images downloaded
# pine Pinus sylvestris: 175 images downloaded
# pine Pinus strobus: 174 images downloaded
# pine Pinus ponderosa: 177 images downloaded
# pine Pinus nigra: 174 images downloaded
# pine Pinus contorta: 175 images downloaded
# palm Elaeis guineensis: 174 images downloaded
# palm Cocos nucifera: 192 images downloaded
# orchid Phalaenopsis orchids: 174 images downloaded
# orchid Oncidium orchids: 174 images downloaded
# orchid Dendrobium orchids: 174 images downloaded
# oak Quercus suber: 173 images downloaded
# oak Quercus coccinea: 174 images downloaded
# oak Quercus alba: 175 images downloaded
# maple Acer palmatum: 184 images downloaded
# maple Acer macrophyllum: 174 images downloaded
# lily Lilium martagon: 174 images downloaded
# lily Lilium speciosum: 174 images downloaded
# fern Athyrium filix-femina: 174 images downloaded
# cactus: 893 images downloaded
# cactus Ferocactus wislizeni: 176 images downloaded
# cactus Carnegiea gigantea: 175 images downloaded

# %%
import os
import random
import shutil

def split_dataset(input_dir, output_dir, train_percent=0.7, val_percent=0.15, test_percent=0.15):
    # Create directories for train, validation, and test sets
    train_dir = os.path.join(output_dir, 'train')
    val_dir = os.path.join(output_dir, 'val')
    test_dir = os.path.join(output_dir, 'test')

    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)
    os.makedirs(test_dir, exist_ok=True)

    # Iterate through each class directory
    for species in os.listdir(input_dir):
        species_dir = os.path.join(input_dir, species)

        # Create corresponding directories in train, val, test sets
        os.makedirs(os.path.join(train_dir, species), exist_ok=True)
        os.makedirs(os.path.join(val_dir, species), exist_ok=True)
        os.makedirs(os.path.join(test_dir, species), exist_ok=True)

        # Iterate through each subspecies directory
        for subspecies in os.listdir(species_dir):
            subspecies_dir = os.path.join(species_dir, subspecies)

            # Get list of image files in subspecies directory
            images = os.listdir(subspecies_dir)
            random.shuffle(images)  # Shuffle to randomize the order

            # Split images into train, val, test sets
            num_images = len(images)
            num_train = int(train_percent * num_images)
            num_val = int(val_percent * num_images)

            train_images = images[:num_train]
            val_images = images[num_train:num_train+num_val]
            test_images = images[num_train+num_val:]

            # Copy images to respective directories
            for img in train_images:
                shutil.copy(os.path.join(subspecies_dir, img), os.path.join(train_dir, species, img))
            for img in val_images:
                shutil.copy(os.path.join(subspecies_dir, img), os.path.join(val_dir, species, img))
            for img in test_images:
                shutil.copy(os.path.join(subspecies_dir, img), os.path.join(test_dir, species, img))

# Example usage: Split dataset into train, val, test sets
input_dir = "/drive/My Drive/Colab Notebooks/plant_subspecies_dataset"
output_dir = "/drive/My Drive/Colab Notebooks/plant_subspecies_split"

split_dataset(input_dir, output_dir)
